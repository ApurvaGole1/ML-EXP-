# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Import breast cancer dataset
from sklearn.datasets import load_breast_cancer
data=load_breast_cancer()
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
# Checking output classes
print(data['target_names'])
# Out:
# ['malignant' 'benign']

# %%
# Checking input attributes
print(data['feature_names'])
# Out:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']

# %%
df1=pd.DataFrame(data['data'],columns=data['feature_names'])

# %%
scaling=StandardScaler()

# %%
scaling.fit(df1)
Scaled_data=scaling.transform(df1)

# %%
principal=PCA(n_components=3)
principal.fit(Scaled_data)
x=principal.transform(Scaled_data)

# %%
print(x.shape)
# Out:
# (569, 3)

# %%
principal.components_
# Out:
# array([[ 0.21890244,  0.10372458,  0.22753729,  0.22099499,  0.14258969,
#          0.23928535,  0.25840048,  0.26085376,  0.13816696,  0.06436335,
#          0.20597878,  0.01742803,  0.21132592,  0.20286964,  0.01453145,
#          0.17039345,  0.15358979,  0.1834174 ,  0.04249842,  0.10256832,
#          0.22799663,  0.10446933,  0.23663968,  0.22487053,  0.12795256,
#          0.21009588,  0.22876753,  0.25088597,  0.12290456,  0.13178394],
#        [-0.23385713, -0.05970609, -0.21518136, -0.23107671,  0.18611302,
#          0.15189161,  0.06016536, -0.0347675 ,  0.19034877,  0.36657547,
#         -0.10555215,  0.08997968, -0.08945723, -0.15229263,  0.20443045,
#          0.2327159 ,  0.19720728,  0.13032156,  0.183848  ,  0.28009203,
#         -0.21986638, -0.0454673 , -0.19987843, -0.21935186,  0.17230435,
#          0.14359317,  0.09796411, -0.00825724,  0.14188335,  0.27533947],
#        [-0.00853124,  0.06454989, -0.00931422,  0.02869953, -0.10429185,
#         -0.07409155,  0.00273381, -0.02556358, -0.04023993, -0.02257411,
#          0.26848138,  0.37463366,  0.26664536,  0.21600654,  0.30883895,
#          0.1547798 ,  0.17646379,  0.22465753,  0.28858427,  0.21150377,
#         -0.04750698, -0.0422978 , -0.0485465 , -0.0119023 , -0.25979758,
#         -0.23607561, -0.17305736, -0.17034413, -0.27131263, -0.23279137]])

# %%
plt.figure(figsize=(5,5))
plt.scatter(x[:,0],x[:,1],c=data['target'],cmap='plasma')
plt.xlabel('PC_1')
plt.ylabel('PC_2')
# Out:
# Text(0, 0.5, 'PC_2')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(5,5))

# %%
axis = fig.add_subplot(111,projection='3d')

# %%
fig = plt.figure()
axis = fig.add_subplot(111, projection='3d')
axis.scatter(x[:,0], x[:,1], x[:,2], c=list(data['target']), cmap = 'plasma')
axis.set_xlabel("PC1", frontsize=10)
axis.set_ylabel("PC2", frontsize=10)
axis.set_zlabel("PC3", frontsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-f8b5f5e0e242> in <cell line: 4>()
#       2 axis = fig.add_subplot(111, projection='3d')
#       3 axis.scatter(x[:,0], x[:,1], x[:,2], c=list(data['target']), cmap = 'plasma')
# ----> 4 axis.set_xlabel("PC1", frontsize=10)
#       5 axis.set_ylabel("PC2", frontsize=10)
#       6 axis.set_zlabel("PC3", frontsize=10)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3468             kwargs.update(x=x, horizontalalignment=loc)
#    3469
# -> 3470         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#    3471
#    3472     def invert_xaxis(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_label_text(self, label, fontdict, **kwargs)
#    1786         if fontdict is not None:
#    1787             self.label.update(fontdict)
# -> 1788         self.label.update(kwargs)
#    1789         self.stale = True
#    1790         return self.label
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/text.py in update(self, kwargs)
#     229         # Update bbox last, as it depends on font properties.
#     230         bbox = kwargs.pop("bbox", sentinel)
# --> 231         super().update(kwargs)
#     232         if bbox is not sentinel:
#     233             self.set_bbox(bbox)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in update(self, props)
#    1211         props : dict
#    1212         """
# -> 1213         return self._update_props(
#    1214             props, "{cls.__name__!r} object has no property {prop_name!r}")
#    1215
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1195                     func = getattr(self, f"set_{k}", None)
#    1196                     if not callable(func):
# -> 1197                         raise AttributeError(
#    1198                             errfmt.format(cls=type(self), prop_name=k))
#    1199                     ret.append(func(v))
#
# AttributeError: 'Text' object has no property 'frontsize'

# %%
print(principal.explained_variance_ratio_)
# Out:
# [0.44272026 0.18971182 0.09393163]
